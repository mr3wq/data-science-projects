# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# Load your dataset here
df = pd.read_csv('your_dataset.csv')

# Data Preprocessing and EDA
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Time Series Decomposition (Trend, Seasonality, Residual)
# Decompose and plot here
# Import necessary libraries
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Create a sample time series data (replace this with your actual data)
# Assuming 'df' is your DataFrame and 'SalesAmount' is the column you want to analyze
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['SalesAmount'], freq=12)  # Replace freq with the seasonality in your data

# Extract components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plotting the decomposition components
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(df['SalesAmount'], label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# Build ARIMA model
model = ARIMA(df['SalesAmount'], order=(1,1,1))
model_fit = model.fit(disp=0)

# Forecasting
forecast = model_fit.forecast(steps=30)[0]

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, forecast))
